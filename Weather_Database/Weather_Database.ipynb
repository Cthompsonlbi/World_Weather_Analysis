# %%
#Import the dependicies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy
# api.openweathermap.org/data/2.5/weather?q=city&appid=d26e3f45135f0789f149c8e45356cfe2
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create and Empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list
#for i in range(len(cities)):
for i, city in enumerate(cities):
        
    #Group cities in sets of 50 for logging purposes
    if(i % 50 ==0 and i > 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record and set numbers and the city.
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record1 of Set 1 | manzhouli
# Processing Record2 of Set 1 | biloli
# Processing Record3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record4 of Set 1 | dingle
# Processing Record5 of Set 1 | amboasary
# Processing Record6 of Set 1 | abu dhabi
# Processing Record7 of Set 1 | bengkulu
# Processing Record8 of Set 1 | korla
# Processing Record9 of Set 1 | rikitea
# Processing Record10 of Set 1 | solano
# Processing Record11 of Set 1 | hokitika
# Processing Record12 of Set 1 | kermanshah
# Processing Record13 of Set 1 | kiama
# Processing Record14 of Set 1 | muncar
# Processing Record15 of Set 1 | kapaa
# Processing Record16 of Set 1 | atuona
# Processing Record17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record18 of Set 1 | dingli
# Processing Record19 of Set 1 | chokurdakh
# Processing Record20 of Set 1 | new norfolk
# Processing Record21 of Set 1 | dikson
# Processing Record22 of Set 1 | kodiak
# Processing Record23 of Set 1 | hanumangarh
# Processing Record24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record25 of Set 1 | comodoro rivadavia
# Processing Record26 of Set 1 | drovyanaya
# Processing Record27 of Set 1 | valentin gomez farias
# Processing Record28 of Set 1 | ushuaia
# Processing Record29 of Set 1 | mataura
# Processing Record30 of Set 1 | avarua
# Processing Record31 of Set 1 | vila franca do campo
# Processing Record32 of Set 1 | guane
# Processing Record33 of Set 1 | ndele
# Processing Record34 of Set 1 | yellowknife
# Processing Record35 of Set 1 | moron
# Processing Record36 of Set 1 | vaini
# Processing Record37 of Set 1 | ancud
# Processing Record38 of Set 1 | bambous virieux
# Processing Record39 of Set 1 | albany
# Processing Record40 of Set 1 | derbent
# Processing Record41 of Set 1 | touros
# Processing Record42 of Set 1 | la ronge
# Processing Record43 of Set 1 | cabo san lucas
# Processing Record44 of Set 1 | jamestown
# Processing Record45 of Set 1 | coalcoman
# City not found. Skipping...
# Processing Record46 of Set 1 | punta arenas
# Processing Record47 of Set 1 | port alfred
# Processing Record48 of Set 1 | oulainen
# Processing Record49 of Set 1 | vao
# Processing Record50 of Set 1 | ribeira grande
# Processing Record51 of Set 1 | opuwo
# Processing Record52 of Set 1 | rundu
# Processing Record53 of Set 1 | praia da vitoria
# Processing Record54 of Set 1 | makakilo city
# Processing Record55 of Set 1 | bilma
# Processing Record56 of Set 1 | pirojpur
# Processing Record57 of Set 1 | yashkul
# Processing Record58 of Set 1 | eureka
# Processing Record59 of Set 1 | mali
# Processing Record60 of Set 1 | chuy
# Processing Record61 of Set 1 | palauig
# Processing Record62 of Set 1 | rio grande
# Processing Record63 of Set 1 | bluff
# Processing Record64 of Set 1 | aripuana
# Processing Record65 of Set 1 | vanimo
# Processing Record66 of Set 1 | langxiang
# Processing Record67 of Set 1 | acapulco
# Processing Record68 of Set 1 | mastung
# Processing Record69 of Set 1 | saint george
# Processing Record70 of Set 1 | qaanaaq
# Processing Record71 of Set 1 | andra
# Processing Record72 of Set 1 | vestmannaeyjar
# Processing Record73 of Set 1 | chiriqui grande
# Processing Record74 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record75 of Set 1 | fairbanks
# Processing Record76 of Set 1 | banyo
# Processing Record77 of Set 1 | bar harbor
# Processing Record78 of Set 1 | svetlogorsk
# Processing Record79 of Set 1 | jalu
# Processing Record80 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record81 of Set 1 | hermanus
# Processing Record82 of Set 1 | pafos
# Processing Record83 of Set 1 | hilo
# Processing Record84 of Set 1 | hofn
# Processing Record85 of Set 1 | dicabisagan
# Processing Record86 of Set 1 | rio brilhante
# Processing Record87 of Set 1 | esperance
# Processing Record88 of Set 1 | viedma
# Processing Record89 of Set 1 | longyearbyen
# Processing Record90 of Set 1 | bandarban
# Processing Record91 of Set 1 | hamilton
# Processing Record92 of Set 1 | quime
# Processing Record93 of Set 1 | arica
# Processing Record94 of Set 1 | puerto ayora
# Processing Record95 of Set 1 | namibe
# Processing Record96 of Set 1 | nikolskoye
# Processing Record97 of Set 1 | portland
# Processing Record98 of Set 1 | yatou
# Processing Record99 of Set 1 | uvalde
# Processing Record100 of Set 1 | matagami
# Processing Record1 of Set 2 | loei
# Processing Record2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record3 of Set 2 | sola
# Processing Record4 of Set 2 | east london
# Processing Record5 of Set 2 | benguela
# Processing Record6 of Set 2 | tuktoyaktuk
# Processing Record7 of Set 2 | hearst
# Processing Record8 of Set 2 | altay
# Processing Record9 of Set 2 | umarkot
# Processing Record10 of Set 2 | jinji
# Processing Record11 of Set 2 | gamba
# Processing Record12 of Set 2 | marawi
# Processing Record13 of Set 2 | santa cruz
# Processing Record14 of Set 2 | chapais
# Processing Record15 of Set 2 | kundgol
# Processing Record16 of Set 2 | nanortalik
# Processing Record17 of Set 2 | castro
# Processing Record18 of Set 2 | winnemucca
# Processing Record19 of Set 2 | butaritari
# Processing Record20 of Set 2 | mukhen
# Processing Record21 of Set 2 | richards bay
# Processing Record22 of Set 2 | lebu
# Processing Record23 of Set 2 | houston
# Processing Record24 of Set 2 | khani
# Processing Record25 of Set 2 | lubumbashi
# Processing Record26 of Set 2 | tiksi
# Processing Record27 of Set 2 | tidore
# City not found. Skipping...
# Processing Record28 of Set 2 | weligama
# Processing Record29 of Set 2 | bilibino
# Processing Record30 of Set 2 | clyde river
# Processing Record31 of Set 2 | antofagasta
# Processing Record32 of Set 2 | straumen
# Processing Record33 of Set 2 | hede
# Processing Record34 of Set 2 | katsuura
# Processing Record35 of Set 2 | balyaga
# Processing Record36 of Set 2 | constitucion
# Processing Record37 of Set 2 | tasiilaq
# Processing Record38 of Set 2 | kuche
# City not found. Skipping...
# Processing Record39 of Set 2 | san quintin
# Processing Record40 of Set 2 | amarante do maranhao
# Processing Record41 of Set 2 | safaga
# Processing Record42 of Set 2 | cuenca
# Processing Record43 of Set 2 | la seyne-sur-mer
# Processing Record44 of Set 2 | mogok
# Processing Record45 of Set 2 | bethel
# Processing Record46 of Set 2 | cape town
# Processing Record47 of Set 2 | yakima
# Processing Record48 of Set 2 | nyurba
# Processing Record49 of Set 2 | saint-philippe
# Processing Record50 of Set 2 | porto novo
# Processing Record1 of Set 3 | nara
# Processing Record2 of Set 3 | tuatapere
# Processing Record3 of Set 3 | kruisfontein
# Processing Record4 of Set 3 | thompson
# Processing Record5 of Set 3 | amapa
# Processing Record6 of Set 3 | kiruna
# Processing Record7 of Set 3 | norman wells
# Processing Record8 of Set 3 | nileshwar
# Processing Record9 of Set 3 | sao filipe
# Processing Record10 of Set 3 | torbay
# Processing Record11 of Set 3 | ponta do sol
# Processing Record12 of Set 3 | hobart
# Processing Record13 of Set 3 | kultuk
# Processing Record14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record15 of Set 3 | hermagor
# Processing Record16 of Set 3 | fortuna
# Processing Record17 of Set 3 | busselton
# Processing Record18 of Set 3 | upernavik
# Processing Record19 of Set 3 | alabaster
# Processing Record20 of Set 3 | ipixuna
# Processing Record21 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record22 of Set 3 | kalmunai
# Processing Record23 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record24 of Set 3 | husavik
# Processing Record25 of Set 3 | rengo
# Processing Record26 of Set 3 | labuhan
# Processing Record27 of Set 3 | maturin
# Processing Record28 of Set 3 | guerrero negro
# Processing Record29 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record30 of Set 3 | musoma
# Processing Record31 of Set 3 | arlit
# Processing Record32 of Set 3 | kichmengskiy gorodok
# Processing Record33 of Set 3 | yumen
# Processing Record34 of Set 3 | klaksvik
# Processing Record35 of Set 3 | rungata
# City not found. Skipping...
# Processing Record36 of Set 3 | abalak
# Processing Record37 of Set 3 | zilair
# Processing Record38 of Set 3 | dunedin
# Processing Record39 of Set 3 | alofi
# Processing Record40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record41 of Set 3 | ungheni
# Processing Record42 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record43 of Set 3 | carnarvon
# Processing Record44 of Set 3 | ostrovnoy
# Processing Record45 of Set 3 | zhanaozen
# Processing Record46 of Set 3 | katherine
# Processing Record47 of Set 3 | faanui
# Processing Record48 of Set 3 | alta floresta
# Processing Record49 of Set 3 | sisimiut
# Processing Record50 of Set 3 | maceio
# Processing Record1 of Set 4 | redding
# Processing Record2 of Set 4 | mahebourg
# Processing Record3 of Set 4 | puerto morazan
# Processing Record4 of Set 4 | hithadhoo
# Processing Record5 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record6 of Set 4 | baniyas
# Processing Record7 of Set 4 | dawei
# Processing Record8 of Set 4 | ilulissat
# Processing Record9 of Set 4 | englewood
# Processing Record10 of Set 4 | tucuman
# Processing Record11 of Set 4 | fare
# Processing Record12 of Set 4 | novo aripuana
# Processing Record13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record14 of Set 4 | edson
# Processing Record15 of Set 4 | teknaf
# Processing Record16 of Set 4 | churapcha
# Processing Record17 of Set 4 | bubaque
# Processing Record18 of Set 4 | hasaki
# Processing Record19 of Set 4 | rawson
# Processing Record20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record21 of Set 4 | bathsheba
# Processing Record22 of Set 4 | iwanai
# Processing Record23 of Set 4 | oranjestad
# Processing Record24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record25 of Set 4 | sinnai
# Processing Record26 of Set 4 | arraial do cabo
# Processing Record27 of Set 4 | brae
# Processing Record28 of Set 4 | edd
# Processing Record29 of Set 4 | khatanga
# Processing Record30 of Set 4 | barrow
# Processing Record31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record33 of Set 4 | tessalit
# Processing Record34 of Set 4 | coahuayana
# Processing Record35 of Set 4 | port hardy
# Processing Record36 of Set 4 | bredasdorp
# Processing Record37 of Set 4 | dillon
# Processing Record38 of Set 4 | airai
# Processing Record39 of Set 4 | belaya gora
# Processing Record40 of Set 4 | hambantota
# Processing Record41 of Set 4 | vohibinany
# Processing Record42 of Set 4 | bongandanga
# Processing Record43 of Set 4 | arvika
# Processing Record44 of Set 4 | takaka
# Processing Record45 of Set 4 | port lincoln
# Processing Record46 of Set 4 | isangel
# Processing Record47 of Set 4 | kaitangata
# Processing Record48 of Set 4 | pisco
# Processing Record49 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record50 of Set 4 | saskylakh
# Processing Record1 of Set 5 | komsomolskiy
# Processing Record2 of Set 5 | parrsboro
# Processing Record3 of Set 5 | razole
# Processing Record4 of Set 5 | mayo
# Processing Record5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record6 of Set 5 | shimoda
# Processing Record7 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record8 of Set 5 | labutta
# City not found. Skipping...
# Processing Record9 of Set 5 | sao felix do xingu
# Processing Record10 of Set 5 | buraydah
# Processing Record11 of Set 5 | port macquarie
# Processing Record12 of Set 5 | lazaro cardenas
# Processing Record13 of Set 5 | mendeleyevsk
# Processing Record14 of Set 5 | turayf
# Processing Record15 of Set 5 | tautira
# Processing Record16 of Set 5 | safwah
# City not found. Skipping...
# Processing Record17 of Set 5 | denpasar
# Processing Record18 of Set 5 | camacupa
# Processing Record19 of Set 5 | vila velha
# Processing Record20 of Set 5 | saint anthony
# Processing Record21 of Set 5 | mao
# Processing Record22 of Set 5 | asau
# Processing Record23 of Set 5 | ambon
# Processing Record24 of Set 5 | inhambane
# Processing Record25 of Set 5 | vardo
# Processing Record26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record27 of Set 5 | hervey bay
# Processing Record28 of Set 5 | leningradskiy
# Processing Record29 of Set 5 | ajdabiya
# Processing Record30 of Set 5 | zuwarah
# Processing Record31 of Set 5 | santiago del estero
# Processing Record32 of Set 5 | teahupoo
# Processing Record33 of Set 5 | samarai
# Processing Record34 of Set 5 | severo-kurilsk
# Processing Record35 of Set 5 | burlington
# Processing Record36 of Set 5 | mulege
# Processing Record37 of Set 5 | krasnoarmeysk
# Processing Record38 of Set 5 | filadelfia
# Processing Record39 of Set 5 | pitiquito
# Processing Record40 of Set 5 | roanoke
# Processing Record41 of Set 5 | cherskiy
# Processing Record42 of Set 5 | ratnagiri
# Processing Record43 of Set 5 | haines junction
# Processing Record44 of Set 5 | cidreira
# Processing Record45 of Set 5 | kaeo
# Processing Record46 of Set 5 | pacific grove
# Processing Record47 of Set 5 | san matias
# Processing Record48 of Set 5 | tingo maria
# Processing Record49 of Set 5 | agua dulce
# Processing Record50 of Set 5 | alenquer
# Processing Record1 of Set 6 | rioblanco
# Processing Record2 of Set 6 | qaqortoq
# Processing Record3 of Set 6 | kapuskasing
# Processing Record4 of Set 6 | grand-lahou
# Processing Record5 of Set 6 | aklavik
# Processing Record6 of Set 6 | fengrun
# Processing Record7 of Set 6 | krasnoselkup
# Processing Record8 of Set 6 | lompoc
# Processing Record9 of Set 6 | tura
# Processing Record10 of Set 6 | sioux lookout
# Processing Record11 of Set 6 | moree
# Processing Record12 of Set 6 | new plymouth
# Processing Record13 of Set 6 | kahului
# Processing Record14 of Set 6 | mount pleasant
# Processing Record15 of Set 6 | olesnica
# Processing Record16 of Set 6 | geraldton
# Processing Record17 of Set 6 | namatanai
# Processing Record18 of Set 6 | birao
# Processing Record19 of Set 6 | bargal
# City not found. Skipping...
# Processing Record20 of Set 6 | sur
# Processing Record21 of Set 6 | port elizabeth
# Processing Record22 of Set 6 | dalkola
# Processing Record23 of Set 6 | kudahuvadhoo
# Processing Record24 of Set 6 | glamoc
# Processing Record25 of Set 6 | tarakan
# Processing Record26 of Set 6 | ulaangom
# Processing Record27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record28 of Set 6 | halifax
# Processing Record29 of Set 6 | port blair
# Processing Record30 of Set 6 | asyut
# Processing Record31 of Set 6 | victor harbor
# Processing Record32 of Set 6 | nueva loja
# Processing Record33 of Set 6 | sitka
# Processing Record34 of Set 6 | alice springs
# Processing Record35 of Set 6 | khandbari
# Processing Record36 of Set 6 | college
# Processing Record37 of Set 6 | champerico
# Processing Record38 of Set 6 | laguna
# Processing Record39 of Set 6 | longavi
# Processing Record40 of Set 6 | moroni
# Processing Record41 of Set 6 | mangrol
# Processing Record42 of Set 6 | hatta
# Processing Record43 of Set 6 | los llanos de aridane
# Processing Record44 of Set 6 | coquimbo
# Processing Record45 of Set 6 | salalah
# Processing Record46 of Set 6 | flinders
# Processing Record47 of Set 6 | atasu
# Processing Record48 of Set 6 | kismayo
# Processing Record49 of Set 6 | victoria
# Processing Record50 of Set 6 | paamiut
# Processing Record1 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record2 of Set 7 | hastings
# Processing Record3 of Set 7 | sao lourenco do sul
# Processing Record4 of Set 7 | itarema
# Processing Record5 of Set 7 | coihaique
# Processing Record6 of Set 7 | boshkengash
# Processing Record7 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record8 of Set 7 | nyuksenitsa
# Processing Record9 of Set 7 | sampit
# Processing Record10 of Set 7 | morondava
# Processing Record11 of Set 7 | malanje
# Processing Record12 of Set 7 | caldwell
# Processing Record13 of Set 7 | foggia
# Processing Record14 of Set 7 | nome
# Processing Record15 of Set 7 | kavaratti
# Processing Record16 of Set 7 | ayr
# Processing Record17 of Set 7 | naze
# Processing Record18 of Set 7 | manzanillo
# Processing Record19 of Set 7 | zomba
# Processing Record20 of Set 7 | henties bay
# Processing Record21 of Set 7 | sao cristovao
# Processing Record22 of Set 7 | ust-barguzin
# Processing Record23 of Set 7 | knysna
# Processing Record24 of Set 7 | sechura
# Processing Record25 of Set 7 | mocuba
# Processing Record26 of Set 7 | hohhot
# Processing Record27 of Set 7 | puerto baquerizo moreno
# Processing Record28 of Set 7 | mezen
# Processing Record29 of Set 7 | el cope
# Processing Record30 of Set 7 | acari
# Processing Record31 of Set 7 | petatlan
# Processing Record32 of Set 7 | maxixe
# Processing Record33 of Set 7 | matamoros
# Processing Record34 of Set 7 | saldanha
# Processing Record35 of Set 7 | yerbogachen
# Processing Record36 of Set 7 | kannangad
# Processing Record37 of Set 7 | gandai
# Processing Record38 of Set 7 | catamarca
# Processing Record39 of Set 7 | ketchikan
# Processing Record40 of Set 7 | revelstoke
# Processing Record41 of Set 7 | san patricio
# Processing Record42 of Set 7 | guangyuan
# Processing Record43 of Set 7 | inirida
# Processing Record44 of Set 7 | itaporanga
# Processing Record45 of Set 7 | berdigestyakh
# Processing Record46 of Set 7 | noyabrsk
# Processing Record47 of Set 7 | kholodnyy
# Processing Record48 of Set 7 | kamaishi
# Processing Record49 of Set 7 | bonavista
# Processing Record50 of Set 7 | mirandola
# Processing Record1 of Set 8 | yelizovo
# Processing Record2 of Set 8 | kushmurun
# Processing Record3 of Set 8 | derzhavinsk
# Processing Record4 of Set 8 | lorena
# Processing Record5 of Set 8 | caravelas
# Processing Record6 of Set 8 | san
# Processing Record7 of Set 8 | kaspiysk
# Processing Record8 of Set 8 | mountain home
# Processing Record9 of Set 8 | hobyo
# Processing Record10 of Set 8 | aflu
# City not found. Skipping...
# Processing Record11 of Set 8 | vila do maio
# Processing Record12 of Set 8 | barcelos
# Processing Record13 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record14 of Set 8 | tazmalt
# Processing Record15 of Set 8 | provideniya
# Processing Record16 of Set 8 | sakakah
# Processing Record17 of Set 8 | patzite
# Processing Record18 of Set 8 | mormugao
# Processing Record19 of Set 8 | rawatsar
# Processing Record20 of Set 8 | altamira
# Processing Record21 of Set 8 | uige
# Processing Record22 of Set 8 | zhigansk
# Processing Record23 of Set 8 | letpadan
# Processing Record24 of Set 8 | grindavik
# Processing Record25 of Set 8 | black river
# Processing Record26 of Set 8 | mar del plata
# Processing Record27 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record28 of Set 8 | camacha
# Processing Record29 of Set 8 | san clemente
# Processing Record30 of Set 8 | amatenango del valle
# Processing Record31 of Set 8 | suhum
# Processing Record32 of Set 8 | puerto cabello
# Processing Record33 of Set 8 | fairlie
# Processing Record34 of Set 8 | gorom-gorom
# Processing Record35 of Set 8 | iberia
# Processing Record36 of Set 8 | chulym
# Processing Record37 of Set 8 | jizan
# Processing Record38 of Set 8 | port pirie
# Processing Record39 of Set 8 | novobiryusinskiy
# Processing Record40 of Set 8 | nishihara
# Processing Record41 of Set 8 | xining
# Processing Record42 of Set 8 | surt
# Processing Record43 of Set 8 | novobirilyussy
# Processing Record44 of Set 8 | margate
# Processing Record45 of Set 8 | aljezur
# Processing Record46 of Set 8 | oistins
# Processing Record47 of Set 8 | yulara
# Processing Record48 of Set 8 | luena
# Processing Record49 of Set 8 | waslala
# Processing Record50 of Set 8 | zavallya
# Processing Record1 of Set 9 | kimbe
# Processing Record2 of Set 9 | zhuozhou
# City not found. Skipping...
# Processing Record3 of Set 9 | byron bay
# Processing Record4 of Set 9 | auki
# Processing Record5 of Set 9 | copiapo
# Processing Record6 of Set 9 | roding
# Processing Record7 of Set 9 | zaozerne
# Processing Record8 of Set 9 | brunico
# Processing Record9 of Set 9 | jumla
# Processing Record10 of Set 9 | qeshm
# Processing Record11 of Set 9 | bolkhov
# Processing Record12 of Set 9 | talara
# Processing Record13 of Set 9 | diego de almagro
# Processing Record14 of Set 9 | kirkkonummi
# Processing Record15 of Set 9 | bedesa
# Processing Record16 of Set 9 | bowen
# Processing Record17 of Set 9 | veraval
# Processing Record18 of Set 9 | khandyga
# Processing Record19 of Set 9 | vanavara
# Processing Record20 of Set 9 | lima
# Processing Record21 of Set 9 | lundazi
# Processing Record22 of Set 9 | ozernovskiy
# Processing Record23 of Set 9 | west wendover
# Processing Record24 of Set 9 | havre-saint-pierre
# Processing Record25 of Set 9 | bereda
# Processing Record26 of Set 9 | poum
# Processing Record27 of Set 9 | te anau
# Processing Record28 of Set 9 | nantucket
# Processing Record29 of Set 9 | desna
# Processing Record30 of Set 9 | bell ville
# Processing Record31 of Set 9 | tigil
# Processing Record32 of Set 9 | havelock
# Processing Record33 of Set 9 | general roca
# Processing Record34 of Set 9 | iqaluit
# Processing Record35 of Set 9 | deder
# Processing Record36 of Set 9 | alihe
# Processing Record37 of Set 9 | fallon
# Processing Record38 of Set 9 | codrington
# Processing Record39 of Set 9 | moba
# Processing Record40 of Set 9 | luderitz
# Processing Record41 of Set 9 | ladario
# Processing Record42 of Set 9 | juneau
# Processing Record43 of Set 9 | lorengau
# Processing Record44 of Set 9 | miri
# Processing Record45 of Set 9 | koumac
# Processing Record46 of Set 9 | cap malheureux
# Processing Record47 of Set 9 | pevek
# Processing Record48 of Set 9 | georgetown
# Processing Record49 of Set 9 | naqadeh
# Processing Record50 of Set 9 | mogadishu
# Processing Record1 of Set 10 | port moresby
# Processing Record2 of Set 10 | mecca
# Processing Record3 of Set 10 | tokur
# Processing Record4 of Set 10 | sao miguel do oeste
# City not found. Skipping...
# Processing Record5 of Set 10 | tyrma
# Processing Record6 of Set 10 | naron
# Processing Record7 of Set 10 | borovichi
# Processing Record8 of Set 10 | kindu
# Processing Record9 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record10 of Set 10 | ustka
# Processing Record11 of Set 10 | gillette
# Processing Record12 of Set 10 | lanigan
# Processing Record13 of Set 10 | vuktyl
# Processing Record14 of Set 10 | aksarka
# Processing Record15 of Set 10 | micheweni
# Processing Record16 of Set 10 | ola
# Processing Record17 of Set 10 | biak
# Processing Record18 of Set 10 | meulaboh
# Processing Record19 of Set 10 | williams lake
# Processing Record20 of Set 10 | kinablangan
# Processing Record21 of Set 10 | lisakovsk
# Processing Record22 of Set 10 | bismarck
# Processing Record23 of Set 10 | noumea
# Processing Record24 of Set 10 | baykit
# Processing Record25 of Set 10 | galle
# Processing Record26 of Set 10 | anadyr
# Processing Record27 of Set 10 | kyra
# Processing Record28 of Set 10 | nefteyugansk
# Processing Record29 of Set 10 | shieli
# Processing Record30 of Set 10 | tambo
# Processing Record31 of Set 10 | scottsbluff
# Processing Record32 of Set 10 | la rioja
# Processing Record33 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record34 of Set 10 | shelburne
# Processing Record35 of Set 10 | sao paulo de olivenca
# Processing Record36 of Set 10 | souris
# Processing Record37 of Set 10 | judaberg
# Processing Record38 of Set 10 | suluova
# Processing Record39 of Set 10 | prudy
# Processing Record40 of Set 10 | olafsvik
# Processing Record41 of Set 10 | capreol
# Processing Record42 of Set 10 | zhuanghe
# Processing Record43 of Set 10 | menongue
# Processing Record44 of Set 10 | pangnirtung
# Processing Record45 of Set 10 | emerald
# Processing Record46 of Set 10 | buin
# Processing Record47 of Set 10 | tual
# Processing Record48 of Set 10 | riyadh
# Processing Record49 of Set 10 | souillac
# Processing Record50 of Set 10 | canoinhas
# Processing Record1 of Set 11 | karratha
# Processing Record2 of Set 11 | alyangula
# Processing Record3 of Set 11 | atherton
# Processing Record4 of Set 11 | nelson bay
# Processing Record5 of Set 11 | seoul
# Processing Record6 of Set 11 | tukrah
# Processing Record7 of Set 11 | makat
# Processing Record8 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record9 of Set 11 | nouadhibou
# Processing Record10 of Set 11 | afua
# Processing Record11 of Set 11 | urusha
# Processing Record12 of Set 11 | kapit
# Processing Record13 of Set 11 | bela
# Processing Record14 of Set 11 | palmer
# Processing Record15 of Set 11 | zemio
# Processing Record16 of Set 11 | northam
# Processing Record17 of Set 11 | baruun-urt
# Processing Record18 of Set 11 | tooele
# Processing Record19 of Set 11 | mount gambier
# Processing Record20 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record21 of Set 11 | torbat-e jam
# Processing Record22 of Set 11 | eyl
# Processing Record23 of Set 11 | maniitsoq
# Processing Record24 of Set 11 | high level
# Processing Record25 of Set 11 | makinsk
# Processing Record26 of Set 11 | vestmanna
# Processing Record27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record28 of Set 11 | alugan
# Processing Record29 of Set 11 | deer lake
# Processing Record30 of Set 11 | loiza
# Processing Record31 of Set 11 | ambulu
# Processing Record32 of Set 11 | kanniyakumari
# Processing Record33 of Set 11 | takapau
# Processing Record34 of Set 11 | evensk
# Processing Record35 of Set 11 | almaznyy
# Processing Record36 of Set 11 | jining
# Processing Record37 of Set 11 | aloleng
# Processing Record38 of Set 11 | grand gaube
# Processing Record39 of Set 11 | wanlaweyn
# Processing Record40 of Set 11 | wau
# Processing Record41 of Set 11 | athabasca
# Processing Record42 of Set 11 | ramos arizpe
# Processing Record43 of Set 11 | bobo dioulasso
# Processing Record44 of Set 11 | vavatenina
# Processing Record45 of Set 11 | fort nelson
# Processing Record46 of Set 11 | mbekenyera
# Processing Record47 of Set 11 | mana
# Processing Record48 of Set 11 | yunhe
# Processing Record49 of Set 11 | lagoa
# Processing Record50 of Set 11 | streator
# Processing Record1 of Set 12 | uyemskiy
# Processing Record2 of Set 12 | half moon bay
# Processing Record3 of Set 12 | solomenskoye
# Processing Record4 of Set 12 | wanning
# Processing Record5 of Set 12 | fort-shevchenko
# Processing Record6 of Set 12 | nova odesa
# Processing Record7 of Set 12 | roma
# Processing Record8 of Set 12 | bacungan
# Processing Record9 of Set 12 | tarata
# Processing Record10 of Set 12 | mpanda
# Processing Record11 of Set 12 | fukue
# Processing Record12 of Set 12 | masjed-e soleyman
# City not found. Skipping...
# Processing Record13 of Set 12 | marsh harbour
# Processing Record14 of Set 12 | taiyuan
# Processing Record15 of Set 12 | tecpan
# Processing Record16 of Set 12 | dong hoi
# Processing Record17 of Set 12 | griffith
# Processing Record18 of Set 12 | thomaston
# Processing Record19 of Set 12 | dhidhdhoo
# Processing Record20 of Set 12 | staryy nadym
# Processing Record21 of Set 12 | tottori
# Processing Record22 of Set 12 | skovorodino
# Processing Record23 of Set 12 | assiniboia
# Processing Record24 of Set 12 | barmer
# Processing Record25 of Set 12 | nuzvid
# Processing Record26 of Set 12 | bima
# Processing Record27 of Set 12 | cambrils
# Processing Record28 of Set 12 | sinjai
# Processing Record29 of Set 12 | abapo
# Processing Record30 of Set 12 | himora
# City not found. Skipping...
# Processing Record31 of Set 12 | saurimo
# Processing Record32 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record33 of Set 12 | chlorakas
# Processing Record34 of Set 12 | ambilobe
# Processing Record35 of Set 12 | buala
# Processing Record36 of Set 12 | kailua
# Processing Record37 of Set 12 | cardoso
# Processing Record38 of Set 12 | at-bashi
# Processing Record39 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record40 of Set 12 | atambua
# Processing Record41 of Set 12 | lakes entrance
# Processing Record42 of Set 12 | broome
# Processing Record43 of Set 12 | orlik
# Processing Record44 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record45 of Set 12 | talnakh
# Processing Record46 of Set 12 | tabou
# Processing Record47 of Set 12 | hovd
# Processing Record48 of Set 12 | arlington
# Processing Record49 of Set 12 | gornopravdinsk
# Processing Record50 of Set 12 | srednekolymsk
# Processing Record1 of Set 13 | ikwiriri
# Processing Record2 of Set 13 | tanabe
# Processing Record3 of Set 13 | san francisco
# Processing Record4 of Set 13 | mabamba
# Processing Record5 of Set 13 | san cristobal
# Processing Record6 of Set 13 | wageningen
# Processing Record7 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record8 of Set 13 | sorong
# Processing Record9 of Set 13 | china
# Processing Record10 of Set 13 | watsa
# Processing Record11 of Set 13 | hudson bay
# Processing Record12 of Set 13 | pathein
# Processing Record13 of Set 13 | gashua
# Processing Record14 of Set 13 | oranjemund
# Processing Record15 of Set 13 | tytuvenai
# Processing Record16 of Set 13 | pokrovsk
# Processing Record17 of Set 13 | vila
# Processing Record18 of Set 13 | mmabatho
# Processing Record19 of Set 13 | adrar
# Processing Record20 of Set 13 | zwedru
# Processing Record21 of Set 13 | bibiani
# Processing Record22 of Set 13 | praia
# Processing Record23 of Set 13 | almenara
# Processing Record24 of Set 13 | kandry
# Processing Record25 of Set 13 | umm lajj
# Processing Record26 of Set 13 | maghama
# City not found. Skipping...
# Processing Record27 of Set 13 | sala consilina
# Processing Record28 of Set 13 | kitimat
# Processing Record29 of Set 13 | conde
# Processing Record30 of Set 13 | rocha
# Processing Record31 of Set 13 | mongo
# Processing Record32 of Set 13 | port keats
# Processing Record33 of Set 13 | shingu
# Processing Record34 of Set 13 | bagan
# Processing Record35 of Set 13 | whyalla
# Processing Record36 of Set 13 | san rafael
# Processing Record37 of Set 13 | hay river
# Processing Record38 of Set 13 | pangkalanbuun
# Processing Record39 of Set 13 | omboue
# Processing Record40 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record41 of Set 13 | whittlesea
# Processing Record42 of Set 13 | ulladulla
# Processing Record43 of Set 13 | waingapu
# Processing Record44 of Set 13 | warren
# Processing Record45 of Set 13 | ures
# Processing Record46 of Set 13 | kavieng
# Processing Record47 of Set 13 | marabba
# Processing Record48 of Set 13 | batemans bay
# Processing Record49 of Set 13 | kurumkan
# Processing Record50 of Set 13 | takoradi
# Processing Record1 of Set 14 | talcahuano
# Processing Record2 of Set 14 | volchikha
# Processing Record3 of Set 14 | saryg-sep
# Processing Record4 of Set 14 | dongsheng
# Processing Record5 of Set 14 | tamandare
# Processing Record6 of Set 14 | ahipara
# Processing Record7 of Set 14 | port hedland
# Processing Record8 of Set 14 | orotukan
# Processing Record9 of Set 14 | romny
# Processing Record10 of Set 14 | west plains
# Processing Record11 of Set 14 | chara
# Processing Record12 of Set 14 | sonoita
# Processing Record13 of Set 14 | ust-nera
# Processing Record14 of Set 14 | jishou
# Processing Record15 of Set 14 | kununurra
# Processing Record16 of Set 14 | rewari
# Processing Record17 of Set 14 | todos santos
# Processing Record18 of Set 14 | kieta
# Processing Record19 of Set 14 | poso
# Processing Record20 of Set 14 | jacareacanga
# Processing Record21 of Set 14 | simao
# Processing Record22 of Set 14 | fasa
# Processing Record23 of Set 14 | channel-port aux basques
# Processing Record24 of Set 14 | dekar
# Processing Record25 of Set 14 | alanya
# Processing Record26 of Set 14 | florence
# Processing Record27 of Set 14 | vangaindrano
# Processing Record28 of Set 14 | launceston
# Processing Record29 of Set 14 | manokwari
# Processing Record30 of Set 14 | chagda
# City not found. Skipping...
# Processing Record31 of Set 14 | yola
# Processing Record32 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record33 of Set 14 | jaipur
# Processing Record34 of Set 14 | tucurui
# Processing Record35 of Set 14 | bulaevo
# Processing Record36 of Set 14 | trinidad
# Processing Record37 of Set 14 | ca mau
# Processing Record38 of Set 14 | kachiry
# Processing Record39 of Set 14 | kenai
# Processing Record40 of Set 14 | tommot
# Processing Record41 of Set 14 | punta alta
# Processing Record42 of Set 14 | plettenberg bay
# Processing Record43 of Set 14 | axim
# Processing Record44 of Set 14 | bambanglipuro
# Processing Record45 of Set 14 | madisonville
# Processing Record46 of Set 14 | necochea
# Processing Record47 of Set 14 | karistos
# City not found. Skipping...
# Processing Record48 of Set 14 | ust-tsilma
# Processing Record49 of Set 14 | murindo
# Processing Record50 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record1 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record2 of Set 15 | sicamous
# Processing Record3 of Set 15 | manicore
# Processing Record4 of Set 15 | tyazhinskiy
# Processing Record5 of Set 15 | descalvado
# Processing Record6 of Set 15 | galesong
# Processing Record7 of Set 15 | jihlava
# Processing Record8 of Set 15 | novopokrovka
# Processing Record9 of Set 15 | yeppoon
# Processing Record10 of Set 15 | puerto asis
# Processing Record11 of Set 15 | vostok
# Processing Record12 of Set 15 | linqing
# Processing Record13 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record14 of Set 15 | aykhal
# Processing Record15 of Set 15 | nguruka
# Processing Record16 of Set 15 | bundaberg
# Processing Record17 of Set 15 | leh
# Processing Record18 of Set 15 | rassvet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Manzhouli  49.6000  117.4333      6.87        99         100        3.74
# 1     Biloli  18.7667   77.7333     66.72        73          85        0.76
# 2     Dingle  10.9995  122.6711     77.41        91         100        6.82
# 3  Amboasary -25.0333   46.3833     67.84        61          33        5.48
# 4  Abu Dhabi  24.4667   54.3667     73.42        88           4        4.61
# 5   Bengkulu  -3.8004  102.2655     75.88        83         100        6.15
# 6      Korla  41.7597   86.1469     30.79        54         100        4.25
# 7    Rikitea -23.1203 -134.9692     76.32        71          99       14.99
# 8     Solano  38.2333 -121.9511     66.52        32           1        0.00
# 9   Hokitika -42.7167  170.9667     58.48        97         100        8.21
#
#   Country Current Description
# 0      CN     overcast clouds
# 1      IN     overcast clouds
# 2      PH     overcast clouds
# 3      MG    scattered clouds
# 4      AE           clear sky
# 5      ID          light rain
# 6      CN     overcast clouds
# 7      PF     overcast clouds
# 8      US                haze
# 9      NZ     overcast clouds

# %%
#Rearrange column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
#Reassigning data frame with rearrange column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Manzhouli      CN  49.6000  117.4333      6.87        99         100
# 1     Biloli      IN  18.7667   77.7333     66.72        73          85
# 2     Dingle      PH  10.9995  122.6711     77.41        91         100
# 3  Amboasary      MG -25.0333   46.3833     67.84        61          33
# 4  Abu Dhabi      AE  24.4667   54.3667     73.42        88           4
# 5   Bengkulu      ID  -3.8004  102.2655     75.88        83         100
# 6      Korla      CN  41.7597   86.1469     30.79        54         100
# 7    Rikitea      PF -23.1203 -134.9692     76.32        71          99
# 8     Solano      US  38.2333 -121.9511     66.52        32           1
# 9   Hokitika      NZ -42.7167  170.9667     58.48        97         100
#
#    Wind Speed Current Description
# 0        3.74     overcast clouds
# 1        0.76     overcast clouds
# 2        6.82     overcast clouds
# 3        5.48    scattered clouds
# 4        4.61           clear sky
# 5        6.15          light rain
# 6        4.25     overcast clouds
# 7       14.99     overcast clouds
# 8        0.00                haze
# 9        8.21     overcast clouds

# %%
#Create the output file(CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
#Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
