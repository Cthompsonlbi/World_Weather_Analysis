# %%
#Import the dependicies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy
# api.openweathermap.org/data/2.5/weather?q=city&appid=d26e3f45135f0789f149c8e45356cfe2
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create and Empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list
#for i in range(len(cities)):
for i, city in enumerate(cities):
        
    #Group cities in sets of 50 for logging purposes
    if(i % 50 ==0 and i > 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record and set numbers and the city.
    print(f"Processing Record{record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record1 of Set 1 | georgetown
# Processing Record2 of Set 1 | khatanga
# Processing Record3 of Set 1 | faya
# Processing Record4 of Set 1 | lashio
# Processing Record5 of Set 1 | burnie
# Processing Record6 of Set 1 | kaitangata
# Processing Record7 of Set 1 | itoman
# Processing Record8 of Set 1 | codrington
# Processing Record9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record10 of Set 1 | hithadhoo
# Processing Record11 of Set 1 | perpignan
# Processing Record12 of Set 1 | belaya gora
# Processing Record13 of Set 1 | comodoro rivadavia
# Processing Record14 of Set 1 | albany
# Processing Record15 of Set 1 | atuona
# Processing Record16 of Set 1 | pevek
# Processing Record17 of Set 1 | jamestown
# Processing Record18 of Set 1 | nhulunbuy
# Processing Record19 of Set 1 | vao
# Processing Record20 of Set 1 | port alfred
# Processing Record21 of Set 1 | dikson
# Processing Record22 of Set 1 | vaini
# Processing Record23 of Set 1 | bluff
# Processing Record24 of Set 1 | piacabucu
# Processing Record25 of Set 1 | cidreira
# Processing Record26 of Set 1 | san jose de guanipa
# Processing Record27 of Set 1 | hurghada
# Processing Record28 of Set 1 | ponta do sol
# Processing Record29 of Set 1 | souillac
# Processing Record30 of Set 1 | sioux lookout
# Processing Record31 of Set 1 | rikitea
# Processing Record32 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record33 of Set 1 | hermanus
# Processing Record34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record35 of Set 1 | chapais
# Processing Record36 of Set 1 | bambous virieux
# Processing Record37 of Set 1 | busselton
# Processing Record38 of Set 1 | fortuna
# Processing Record39 of Set 1 | tuatapere
# Processing Record40 of Set 1 | carnarvon
# Processing Record41 of Set 1 | kapaa
# Processing Record42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record43 of Set 1 | ushuaia
# Processing Record44 of Set 1 | tiksi
# Processing Record45 of Set 1 | mataura
# Processing Record46 of Set 1 | saskylakh
# Processing Record47 of Set 1 | jacareacanga
# Processing Record48 of Set 1 | kayankulam
# Processing Record49 of Set 1 | hobart
# Processing Record50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record51 of Set 1 | nanortalik
# Processing Record52 of Set 1 | fort myers beach
# Processing Record53 of Set 1 | prienai
# Processing Record54 of Set 1 | dingle
# Processing Record55 of Set 1 | port lincoln
# Processing Record56 of Set 1 | sao filipe
# Processing Record57 of Set 1 | lages
# Processing Record58 of Set 1 | saldanha
# Processing Record59 of Set 1 | fairbanks
# Processing Record60 of Set 1 | cabo san lucas
# Processing Record61 of Set 1 | kutum
# Processing Record62 of Set 1 | bom sucesso
# Processing Record63 of Set 1 | alofi
# Processing Record64 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record65 of Set 1 | bethel
# Processing Record66 of Set 1 | north branch
# Processing Record67 of Set 1 | sitka
# Processing Record68 of Set 1 | gazanjyk
# Processing Record69 of Set 1 | rio rancho
# Processing Record70 of Set 1 | labuhan
# Processing Record71 of Set 1 | cherskiy
# Processing Record72 of Set 1 | klyuchi
# Processing Record73 of Set 1 | turbat
# Processing Record74 of Set 1 | east london
# Processing Record75 of Set 1 | axim
# Processing Record76 of Set 1 | mezen
# Processing Record77 of Set 1 | bilibino
# Processing Record78 of Set 1 | bellmead
# Processing Record79 of Set 1 | faanui
# Processing Record80 of Set 1 | hilo
# Processing Record81 of Set 1 | port blair
# Processing Record82 of Set 1 | tilichiki
# Processing Record83 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record84 of Set 1 | norman wells
# Processing Record85 of Set 1 | marcona
# City not found. Skipping...
# Processing Record86 of Set 1 | sakaiminato
# Processing Record87 of Set 1 | minnedosa
# Processing Record88 of Set 1 | nuevo progreso
# Processing Record89 of Set 1 | esperance
# Processing Record90 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record91 of Set 1 | chkalovsk
# Processing Record92 of Set 1 | robertsport
# Processing Record93 of Set 1 | eureka
# Processing Record94 of Set 1 | lompoc
# Processing Record95 of Set 1 | new norfolk
# Processing Record96 of Set 1 | butaritari
# Processing Record97 of Set 1 | kabansk
# Processing Record98 of Set 1 | makat
# Processing Record99 of Set 1 | qaanaaq
# Processing Record100 of Set 1 | kholmogory
# Processing Record1 of Set 2 | charters towers
# Processing Record2 of Set 2 | mexico
# Processing Record3 of Set 2 | yellowknife
# Processing Record4 of Set 2 | kodiak
# Processing Record5 of Set 2 | santo antonio do sudoeste
# Processing Record6 of Set 2 | port elizabeth
# Processing Record7 of Set 2 | aykhal
# Processing Record8 of Set 2 | pedernales
# Processing Record9 of Set 2 | nikolskoye
# Processing Record10 of Set 2 | lebu
# Processing Record11 of Set 2 | mahebourg
# Processing Record12 of Set 2 | aksarayskiy
# Processing Record13 of Set 2 | manokwari
# Processing Record14 of Set 2 | chokurdakh
# Processing Record15 of Set 2 | santa cruz de rosales
# City not found. Skipping...
# Processing Record16 of Set 2 | san patricio
# Processing Record17 of Set 2 | pangnirtung
# Processing Record18 of Set 2 | vardo
# Processing Record19 of Set 2 | torbay
# Processing Record20 of Set 2 | barrow
# Processing Record21 of Set 2 | provideniya
# Processing Record22 of Set 2 | nanyang
# Processing Record23 of Set 2 | punta arenas
# Processing Record24 of Set 2 | laguna
# Processing Record25 of Set 2 | severo-kurilsk
# Processing Record26 of Set 2 | teguldet
# Processing Record27 of Set 2 | whyalla
# Processing Record28 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record30 of Set 2 | zonguldak
# Processing Record31 of Set 2 | shenjiamen
# Processing Record32 of Set 2 | avarua
# Processing Record33 of Set 2 | zhezkazgan
# Processing Record34 of Set 2 | hobyo
# Processing Record35 of Set 2 | arraial do cabo
# Processing Record36 of Set 2 | mutsu
# Processing Record37 of Set 2 | miri
# Processing Record38 of Set 2 | broken hill
# Processing Record39 of Set 2 | ondjiva
# Processing Record40 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record41 of Set 2 | clyde river
# Processing Record42 of Set 2 | kanniyakumari
# Processing Record43 of Set 2 | mubi
# Processing Record44 of Set 2 | ossora
# Processing Record45 of Set 2 | wenling
# Processing Record46 of Set 2 | timbiqui
# Processing Record47 of Set 2 | cape town
# Processing Record48 of Set 2 | chimbote
# Processing Record49 of Set 2 | tual
# Processing Record50 of Set 2 | derzhavinsk
# Processing Record1 of Set 3 | canovanas
# Processing Record2 of Set 3 | svetlogorsk
# Processing Record3 of Set 3 | hamilton
# Processing Record4 of Set 3 | tucurui
# Processing Record5 of Set 3 | tautira
# Processing Record6 of Set 3 | sanjwal
# Processing Record7 of Set 3 | sydney
# Processing Record8 of Set 3 | cabo rojo
# Processing Record9 of Set 3 | yar-sale
# Processing Record10 of Set 3 | syracuse
# Processing Record11 of Set 3 | waipawa
# Processing Record12 of Set 3 | simplicio mendes
# Processing Record13 of Set 3 | valparaiso
# Processing Record14 of Set 3 | dandong
# Processing Record15 of Set 3 | alta floresta
# Processing Record16 of Set 3 | montepuez
# Processing Record17 of Set 3 | talcahuano
# Processing Record18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record19 of Set 3 | luwuk
# Processing Record20 of Set 3 | ambon
# Processing Record21 of Set 3 | biak
# Processing Record22 of Set 3 | mishan
# Processing Record23 of Set 3 | ust-kut
# Processing Record24 of Set 3 | karratha
# Processing Record25 of Set 3 | toliary
# City not found. Skipping...
# Processing Record26 of Set 3 | tasiilaq
# Processing Record27 of Set 3 | gama
# Processing Record28 of Set 3 | saint-georges
# Processing Record29 of Set 3 | narsaq
# Processing Record30 of Set 3 | kamaishi
# Processing Record31 of Set 3 | tuktoyaktuk
# Processing Record32 of Set 3 | yaan
# Processing Record33 of Set 3 | opuwo
# Processing Record34 of Set 3 | condado
# Processing Record35 of Set 3 | kaseda
# Processing Record36 of Set 3 | samarai
# Processing Record37 of Set 3 | kavieng
# Processing Record38 of Set 3 | sao felix do xingu
# Processing Record39 of Set 3 | klaksvik
# Processing Record40 of Set 3 | namibe
# Processing Record41 of Set 3 | iqaluit
# Processing Record42 of Set 3 | dzilam gonzalez
# Processing Record43 of Set 3 | bauta
# Processing Record44 of Set 3 | castro
# Processing Record45 of Set 3 | zhangjiakou
# Processing Record46 of Set 3 | cockburn town
# Processing Record47 of Set 3 | kodinsk
# Processing Record48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record49 of Set 3 | muros
# Processing Record50 of Set 3 | say
# Processing Record1 of Set 4 | puerto ayora
# Processing Record2 of Set 4 | churapcha
# Processing Record3 of Set 4 | doha
# Processing Record4 of Set 4 | meulaboh
# Processing Record5 of Set 4 | quelimane
# Processing Record6 of Set 4 | merauke
# Processing Record7 of Set 4 | bowen
# Processing Record8 of Set 4 | geraldton
# Processing Record9 of Set 4 | turukhansk
# Processing Record10 of Set 4 | brahmapuri
# City not found. Skipping...
# Processing Record11 of Set 4 | marsh harbour
# Processing Record12 of Set 4 | lorengau
# Processing Record13 of Set 4 | nantucket
# Processing Record14 of Set 4 | aklavik
# Processing Record15 of Set 4 | saint-joseph
# Processing Record16 of Set 4 | kruisfontein
# Processing Record17 of Set 4 | pontes e lacerda
# Processing Record18 of Set 4 | ancud
# Processing Record19 of Set 4 | evensk
# Processing Record20 of Set 4 | bredasdorp
# Processing Record21 of Set 4 | yancheng
# Processing Record22 of Set 4 | buala
# Processing Record23 of Set 4 | saly
# Processing Record24 of Set 4 | simao
# Processing Record25 of Set 4 | mount isa
# Processing Record26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record27 of Set 4 | bandarbeyla
# Processing Record28 of Set 4 | dinar
# Processing Record29 of Set 4 | palmas
# Processing Record30 of Set 4 | alyangula
# Processing Record31 of Set 4 | takapau
# Processing Record32 of Set 4 | south lyon
# Processing Record33 of Set 4 | khani
# Processing Record34 of Set 4 | winnemucca
# Processing Record35 of Set 4 | tessalit
# Processing Record36 of Set 4 | tutoia
# Processing Record37 of Set 4 | pangody
# Processing Record38 of Set 4 | port moresby
# Processing Record39 of Set 4 | victoria
# Processing Record40 of Set 4 | sorong
# Processing Record41 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record43 of Set 4 | olafsvik
# Processing Record44 of Set 4 | neiafu
# Processing Record45 of Set 4 | merke
# Processing Record46 of Set 4 | hualmay
# Processing Record47 of Set 4 | changji
# Processing Record48 of Set 4 | virginia beach
# Processing Record49 of Set 4 | san jose
# Processing Record50 of Set 4 | suntar
# Processing Record1 of Set 5 | mar del plata
# Processing Record2 of Set 5 | leshukonskoye
# Processing Record3 of Set 5 | nouadhibou
# Processing Record4 of Set 5 | morondava
# Processing Record5 of Set 5 | saint-pierre
# Processing Record6 of Set 5 | antofagasta
# Processing Record7 of Set 5 | tabuk
# Processing Record8 of Set 5 | naze
# Processing Record9 of Set 5 | pisco
# Processing Record10 of Set 5 | hauterive
# Processing Record11 of Set 5 | shenzhen
# Processing Record12 of Set 5 | japoata
# Processing Record13 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record14 of Set 5 | bambanglipuro
# Processing Record15 of Set 5 | mitsamiouli
# Processing Record16 of Set 5 | manta
# Processing Record17 of Set 5 | wajima
# Processing Record18 of Set 5 | damietta
# Processing Record19 of Set 5 | orbetello
# Processing Record20 of Set 5 | lhokseumawe
# Processing Record21 of Set 5 | lac du bonnet
# Processing Record22 of Set 5 | saint george
# Processing Record23 of Set 5 | menongue
# Processing Record24 of Set 5 | henties bay
# Processing Record25 of Set 5 | burica
# City not found. Skipping...
# Processing Record26 of Set 5 | antalaha
# Processing Record27 of Set 5 | porto murtinho
# Processing Record28 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record29 of Set 5 | beira
# Processing Record30 of Set 5 | hirara
# Processing Record31 of Set 5 | toftir
# City not found. Skipping...
# Processing Record32 of Set 5 | thompson
# Processing Record33 of Set 5 | gainesville
# Processing Record34 of Set 5 | nexo
# Processing Record35 of Set 5 | westport
# Processing Record36 of Set 5 | hasaki
# Processing Record37 of Set 5 | ferlach
# Processing Record38 of Set 5 | palkonda
# Processing Record39 of Set 5 | severo-yeniseyskiy
# Processing Record40 of Set 5 | katsuura
# Processing Record41 of Set 5 | lubango
# Processing Record42 of Set 5 | arcachon
# Processing Record43 of Set 5 | port hardy
# Processing Record44 of Set 5 | a coruna
# Processing Record45 of Set 5 | parrita
# Processing Record46 of Set 5 | saint-philippe
# Processing Record47 of Set 5 | corowa
# Processing Record48 of Set 5 | muroto
# Processing Record49 of Set 5 | dali
# Processing Record50 of Set 5 | medak
# Processing Record1 of Set 6 | krasnoselkup
# Processing Record2 of Set 6 | winslow
# Processing Record3 of Set 6 | sur
# Processing Record4 of Set 6 | adrar
# Processing Record5 of Set 6 | belmonte
# Processing Record6 of Set 6 | calabozo
# Processing Record7 of Set 6 | xai-xai
# Processing Record8 of Set 6 | sao joao del rei
# Processing Record9 of Set 6 | yangjiang
# Processing Record10 of Set 6 | sili
# Processing Record11 of Set 6 | la palma
# Processing Record12 of Set 6 | laje
# Processing Record13 of Set 6 | mweka
# Processing Record14 of Set 6 | vilcun
# Processing Record15 of Set 6 | portland
# Processing Record16 of Set 6 | golden
# Processing Record17 of Set 6 | palencia
# Processing Record18 of Set 6 | bengkulu
# Processing Record19 of Set 6 | san cristobal
# Processing Record20 of Set 6 | matara
# Processing Record21 of Set 6 | atasu
# Processing Record22 of Set 6 | ayorou
# Processing Record23 of Set 6 | rocha
# Processing Record24 of Set 6 | nome
# Processing Record25 of Set 6 | dongzhen
# Processing Record26 of Set 6 | saint-augustin
# Processing Record27 of Set 6 | sao miguel do araguaia
# Processing Record28 of Set 6 | borogontsy
# Processing Record29 of Set 6 | palmares do sul
# Processing Record30 of Set 6 | manggar
# Processing Record31 of Set 6 | constitucion
# Processing Record32 of Set 6 | srednekolymsk
# Processing Record33 of Set 6 | ilulissat
# Processing Record34 of Set 6 | beaverlodge
# Processing Record35 of Set 6 | nowy sacz
# Processing Record36 of Set 6 | avera
# Processing Record37 of Set 6 | kudahuvadhoo
# Processing Record38 of Set 6 | mahibadhoo
# Processing Record39 of Set 6 | leh
# Processing Record40 of Set 6 | berezovyy
# Processing Record41 of Set 6 | rawson
# Processing Record42 of Set 6 | sambava
# Processing Record43 of Set 6 | tongzi
# Processing Record44 of Set 6 | airai
# Processing Record45 of Set 6 | isangel
# Processing Record46 of Set 6 | conde
# Processing Record47 of Set 6 | inhambane
# Processing Record48 of Set 6 | craig
# Processing Record49 of Set 6 | farrukhnagar
# Processing Record50 of Set 6 | maldonado
# Processing Record1 of Set 7 | leningradskiy
# Processing Record2 of Set 7 | isiolo
# Processing Record3 of Set 7 | itamaraca
# Processing Record4 of Set 7 | havelock
# Processing Record5 of Set 7 | sarai alamgir
# Processing Record6 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record7 of Set 7 | xichang
# Processing Record8 of Set 7 | alice springs
# Processing Record9 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record10 of Set 7 | haines junction
# Processing Record11 of Set 7 | huilong
# Processing Record12 of Set 7 | idil
# Processing Record13 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record14 of Set 7 | sirjan
# Processing Record15 of Set 7 | chokwe
# Processing Record16 of Set 7 | bonthe
# Processing Record17 of Set 7 | balkhash
# Processing Record18 of Set 7 | acari
# Processing Record19 of Set 7 | salym
# Processing Record20 of Set 7 | tomatlan
# Processing Record21 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record22 of Set 7 | santa rosa
# Processing Record23 of Set 7 | kimbe
# Processing Record24 of Set 7 | peniche
# Processing Record25 of Set 7 | pecos
# Processing Record26 of Set 7 | bac lieu
# Processing Record27 of Set 7 | wadi maliz
# Processing Record28 of Set 7 | jambol
# City not found. Skipping...
# Processing Record29 of Set 7 | warrington
# Processing Record30 of Set 7 | manga
# Processing Record31 of Set 7 | rumoi
# Processing Record32 of Set 7 | burgeo
# Processing Record33 of Set 7 | umea
# Processing Record34 of Set 7 | muli
# Processing Record35 of Set 7 | riyadh
# Processing Record36 of Set 7 | yermakovskoye
# Processing Record37 of Set 7 | la asuncion
# Processing Record38 of Set 7 | macas
# Processing Record39 of Set 7 | dhidhdhoo
# Processing Record40 of Set 7 | camacha
# Processing Record41 of Set 7 | vikulovo
# Processing Record42 of Set 7 | trincomalee
# Processing Record43 of Set 7 | niksic
# Processing Record44 of Set 7 | okhotsk
# Processing Record45 of Set 7 | zyryanka
# Processing Record46 of Set 7 | iquique
# Processing Record47 of Set 7 | cordele
# Processing Record48 of Set 7 | mogzon
# Processing Record49 of Set 7 | sisimiut
# Processing Record50 of Set 7 | roma
# Processing Record1 of Set 8 | ouesso
# Processing Record2 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record3 of Set 8 | omihachiman
# Processing Record4 of Set 8 | mehamn
# Processing Record5 of Set 8 | sardarshahr
# Processing Record6 of Set 8 | askino
# Processing Record7 of Set 8 | upernavik
# Processing Record8 of Set 8 | beloha
# Processing Record9 of Set 8 | port hueneme
# Processing Record10 of Set 8 | rebrikha
# Processing Record11 of Set 8 | baruun-urt
# Processing Record12 of Set 8 | baykit
# Processing Record13 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record14 of Set 8 | kisangani
# Processing Record15 of Set 8 | castanos
# Processing Record16 of Set 8 | salta
# Processing Record17 of Set 8 | flinders
# Processing Record18 of Set 8 | talnakh
# Processing Record19 of Set 8 | kawhia
# Processing Record20 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record21 of Set 8 | naftah
# City not found. Skipping...
# Processing Record22 of Set 8 | zalantun
# Processing Record23 of Set 8 | bathsheba
# Processing Record24 of Set 8 | pavilosta
# Processing Record25 of Set 8 | dubbo
# Processing Record26 of Set 8 | kieta
# Processing Record27 of Set 8 | xuddur
# Processing Record28 of Set 8 | quchan
# Processing Record29 of Set 8 | concarneau
# Processing Record30 of Set 8 | ulaangom
# Processing Record31 of Set 8 | fort nelson
# Processing Record32 of Set 8 | norfolk
# Processing Record33 of Set 8 | maragogi
# Processing Record34 of Set 8 | rungata
# City not found. Skipping...
# Processing Record35 of Set 8 | kathmandu
# Processing Record36 of Set 8 | sovetskiy
# Processing Record37 of Set 8 | wencheng
# Processing Record38 of Set 8 | sampit
# Processing Record39 of Set 8 | ende
# Processing Record40 of Set 8 | lagoa
# Processing Record41 of Set 8 | north battleford
# Processing Record42 of Set 8 | coquimbo
# Processing Record43 of Set 8 | zhangye
# Processing Record44 of Set 8 | setermoen
# Processing Record45 of Set 8 | vallam
# Processing Record46 of Set 8 | buchanan
# Processing Record47 of Set 8 | dwarka
# Processing Record48 of Set 8 | gallipoli
# Processing Record49 of Set 8 | batsfjord
# Processing Record50 of Set 8 | namatanai
# Processing Record1 of Set 9 | manono
# Processing Record2 of Set 9 | beringovskiy
# Processing Record3 of Set 9 | chulym
# Processing Record4 of Set 9 | quatre cocos
# Processing Record5 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record6 of Set 9 | poum
# Processing Record7 of Set 9 | suleja
# Processing Record8 of Set 9 | vila velha
# Processing Record9 of Set 9 | padang
# Processing Record10 of Set 9 | krutinka
# Processing Record11 of Set 9 | tigil
# Processing Record12 of Set 9 | alekseyevka
# Processing Record13 of Set 9 | nizwa
# Processing Record14 of Set 9 | vila franca do campo
# Processing Record15 of Set 9 | ziro
# Processing Record16 of Set 9 | sawtell
# Processing Record17 of Set 9 | palmer
# Processing Record18 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record19 of Set 9 | nizhnevartovsk
# Processing Record20 of Set 9 | ust-ishim
# Processing Record21 of Set 9 | amapa
# Processing Record22 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record23 of Set 9 | batticaloa
# Processing Record24 of Set 9 | vuktyl
# Processing Record25 of Set 9 | deputatskiy
# Processing Record26 of Set 9 | bhairab bazar
# Processing Record27 of Set 9 | phangnga
# Processing Record28 of Set 9 | verkhnevilyuysk
# Processing Record29 of Set 9 | carora
# Processing Record30 of Set 9 | trelew
# Processing Record31 of Set 9 | caravelas
# Processing Record32 of Set 9 | akhaldaba
# Processing Record33 of Set 9 | lykhivka
# Processing Record34 of Set 9 | noumea
# Processing Record35 of Set 9 | san lawrenz
# Processing Record36 of Set 9 | ous
# Processing Record37 of Set 9 | athabasca
# Processing Record38 of Set 9 | richards bay
# Processing Record39 of Set 9 | ipixuna
# Processing Record40 of Set 9 | ketchikan
# Processing Record41 of Set 9 | lively
# Processing Record42 of Set 9 | melfi
# Processing Record43 of Set 9 | havoysund
# Processing Record44 of Set 9 | xuanhua
# Processing Record45 of Set 9 | perth
# Processing Record46 of Set 9 | erechim
# Processing Record47 of Set 9 | lujiang
# Processing Record48 of Set 9 | gamba
# Processing Record49 of Set 9 | berlevag
# Processing Record50 of Set 9 | the valley
# Processing Record1 of Set 10 | maniitsoq
# Processing Record2 of Set 10 | port hedland
# Processing Record3 of Set 10 | tezu
# Processing Record4 of Set 10 | gat
# Processing Record5 of Set 10 | pasan
# Processing Record6 of Set 10 | cayenne
# Processing Record7 of Set 10 | kailua
# Processing Record8 of Set 10 | ofaqim
# Processing Record9 of Set 10 | christchurch
# Processing Record10 of Set 10 | rundu
# Processing Record11 of Set 10 | rio gallegos
# Processing Record12 of Set 10 | arlit
# Processing Record13 of Set 10 | saint-francois
# Processing Record14 of Set 10 | puerto baquerizo moreno
# Processing Record15 of Set 10 | jumla
# Processing Record16 of Set 10 | port-cartier
# Processing Record17 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record18 of Set 10 | george
# Processing Record19 of Set 10 | kavaratti
# Processing Record20 of Set 10 | yanam
# Processing Record21 of Set 10 | port augusta
# Processing Record22 of Set 10 | karatau
# Processing Record23 of Set 10 | muisne
# Processing Record24 of Set 10 | half moon bay
# Processing Record25 of Set 10 | berdigestyakh
# Processing Record26 of Set 10 | port macquarie
# Processing Record27 of Set 10 | hubli
# Processing Record28 of Set 10 | taoudenni
# Processing Record29 of Set 10 | chuy
# Processing Record30 of Set 10 | port shepstone
# Processing Record31 of Set 10 | marsa matruh
# Processing Record32 of Set 10 | ribeira grande
# Processing Record33 of Set 10 | eustis
# Processing Record34 of Set 10 | teknaf
# Processing Record35 of Set 10 | pitimbu
# Processing Record36 of Set 10 | aflu
# City not found. Skipping...
# Processing Record37 of Set 10 | ponta delgada
# Processing Record38 of Set 10 | prince rupert
# Processing Record39 of Set 10 | mwinilunga
# Processing Record40 of Set 10 | plateros
# Processing Record41 of Set 10 | malko tarnovo
# Processing Record42 of Set 10 | demba
# Processing Record43 of Set 10 | omboue
# Processing Record44 of Set 10 | sexsmith
# Processing Record45 of Set 10 | tocopilla
# Processing Record46 of Set 10 | diffa
# Processing Record47 of Set 10 | brae
# Processing Record48 of Set 10 | pareora
# Processing Record49 of Set 10 | estevan
# Processing Record50 of Set 10 | cam ranh
# Processing Record1 of Set 11 | stephenville
# Processing Record2 of Set 11 | guerrero negro
# Processing Record3 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record4 of Set 11 | roald
# Processing Record5 of Set 11 | longlac
# City not found. Skipping...
# Processing Record6 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record7 of Set 11 | nemuro
# Processing Record8 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record9 of Set 11 | barawe
# City not found. Skipping...
# Processing Record10 of Set 11 | kaka
# Processing Record11 of Set 11 | puerto leguizamo
# Processing Record12 of Set 11 | kenai
# Processing Record13 of Set 11 | adre
# Processing Record14 of Set 11 | douglas
# Processing Record15 of Set 11 | sola
# Processing Record16 of Set 11 | kirakira
# Processing Record17 of Set 11 | aden
# Processing Record18 of Set 11 | korla
# Processing Record19 of Set 11 | pilao arcado
# City not found. Skipping...
# Processing Record20 of Set 11 | horasan
# Processing Record21 of Set 11 | bulgan
# Processing Record22 of Set 11 | curumani
# Processing Record23 of Set 11 | bobota
# Processing Record24 of Set 11 | lagos
# Processing Record25 of Set 11 | bugulma
# Processing Record26 of Set 11 | kosonsoy
# Processing Record27 of Set 11 | wasilla
# Processing Record28 of Set 11 | ovalle
# Processing Record29 of Set 11 | ivybridge
# Processing Record30 of Set 11 | altamira
# Processing Record31 of Set 11 | nata
# Processing Record32 of Set 11 | rusape
# Processing Record33 of Set 11 | kununurra
# Processing Record34 of Set 11 | san vicente
# Processing Record35 of Set 11 | olovyannaya
# Processing Record36 of Set 11 | saint-paul
# Processing Record37 of Set 11 | tsiroanomandidy
# Processing Record38 of Set 11 | kidal
# Processing Record39 of Set 11 | huanren
# Processing Record40 of Set 11 | qingdao
# Processing Record41 of Set 11 | maamba
# Processing Record42 of Set 11 | skjervoy
# Processing Record43 of Set 11 | zhaodong
# Processing Record44 of Set 11 | filadelfia
# Processing Record45 of Set 11 | tucupita
# Processing Record46 of Set 11 | mackay
# Processing Record47 of Set 11 | mount gambier
# Processing Record48 of Set 11 | ouadda
# Processing Record49 of Set 11 | taltal
# Processing Record50 of Set 11 | chenghai
# Processing Record1 of Set 12 | acajutla
# Processing Record2 of Set 12 | moranbah
# Processing Record3 of Set 12 | rach gia
# Processing Record4 of Set 12 | tete
# Processing Record5 of Set 12 | ayan
# Processing Record6 of Set 12 | sawakin
# Processing Record7 of Set 12 | ravar
# Processing Record8 of Set 12 | sibolga
# Processing Record9 of Set 12 | broome
# Processing Record10 of Set 12 | longyearbyen
# Processing Record11 of Set 12 | ostrovnoy
# Processing Record12 of Set 12 | bubaque
# Processing Record13 of Set 12 | chagda
# City not found. Skipping...
# Processing Record14 of Set 12 | bilma
# Processing Record15 of Set 12 | shelburne
# Processing Record16 of Set 12 | tolaga bay
# Processing Record17 of Set 12 | roseburg
# Processing Record18 of Set 12 | ures
# Processing Record19 of Set 12 | khakhea
# Processing Record20 of Set 12 | bababe
# City not found. Skipping...
# Processing Record21 of Set 12 | ebensee
# Processing Record22 of Set 12 | atocha
# Processing Record23 of Set 12 | bichura
# Processing Record24 of Set 12 | nalut
# Processing Record25 of Set 12 | mbacke
# City not found. Skipping...
# Processing Record26 of Set 12 | adana
# Processing Record27 of Set 12 | bandar-e lengeh
# Processing Record28 of Set 12 | gogrial
# Processing Record29 of Set 12 | asau
# Processing Record30 of Set 12 | kikwit
# Processing Record31 of Set 12 | liverpool
# Processing Record32 of Set 12 | sarkand
# Processing Record33 of Set 12 | sosnovka
# Processing Record34 of Set 12 | dakar
# Processing Record35 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record36 of Set 12 | nabire
# Processing Record37 of Set 12 | todos santos
# Processing Record38 of Set 12 | cabedelo
# Processing Record39 of Set 12 | ucluelet
# Processing Record40 of Set 12 | praia
# Processing Record41 of Set 12 | udachnyy
# Processing Record42 of Set 12 | baboua
# City not found. Skipping...
# Processing Record43 of Set 12 | aksu
# Processing Record44 of Set 12 | nizhnyaya poyma
# Processing Record45 of Set 12 | soe
# Processing Record46 of Set 12 | banda aceh
# Processing Record47 of Set 12 | aksarka
# Processing Record48 of Set 12 | ikryanoye
# Processing Record49 of Set 12 | carutapera
# Processing Record50 of Set 12 | soldatskaya
# Processing Record1 of Set 13 | kokopo
# Processing Record2 of Set 13 | alma
# Processing Record3 of Set 13 | upington
# Processing Record4 of Set 13 | duz
# City not found. Skipping...
# Processing Record5 of Set 13 | voh
# Processing Record6 of Set 13 | high level
# Processing Record7 of Set 13 | goundam
# Processing Record8 of Set 13 | victor harbor
# Processing Record9 of Set 13 | sobolevo
# Processing Record10 of Set 13 | ambilobe
# Processing Record11 of Set 13 | vysotsk
# Processing Record12 of Set 13 | komsomolskiy
# Processing Record13 of Set 13 | rodrigues alves
# Processing Record14 of Set 13 | gorom-gorom
# Processing Record15 of Set 13 | luderitz
# Processing Record16 of Set 13 | ust-tsilma
# Processing Record17 of Set 13 | lasa
# Processing Record18 of Set 13 | beaupre
# Processing Record19 of Set 13 | tamworth
# Processing Record20 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record21 of Set 13 | petrolina de goias
# Processing Record22 of Set 13 | azangaro
# Processing Record23 of Set 13 | cervo
# Processing Record24 of Set 13 | tonekabon
# Processing Record25 of Set 13 | yabelo
# Processing Record26 of Set 13 | muncar
# Processing Record27 of Set 13 | kon tum
# Processing Record28 of Set 13 | mirnyy
# Processing Record29 of Set 13 | jalu
# Processing Record30 of Set 13 | kandiari
# Processing Record31 of Set 13 | solnechnyy
# Processing Record32 of Set 13 | cowra
# Processing Record33 of Set 13 | khuzdar
# Processing Record34 of Set 13 | ayios matthaios
# City not found. Skipping...
# Processing Record35 of Set 13 | digha
# Processing Record36 of Set 13 | dekoa
# City not found. Skipping...
# Processing Record37 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record38 of Set 13 | hami
# Processing Record39 of Set 13 | rypin
# Processing Record40 of Set 13 | beidao
# Processing Record41 of Set 13 | arman
# Processing Record42 of Set 13 | huarmey
# Processing Record43 of Set 13 | chornoliztsi
# Processing Record44 of Set 13 | svetlaya
# Processing Record45 of Set 13 | pandan
# Processing Record46 of Set 13 | reconquista
# Processing Record47 of Set 13 | cheremukhovo
# Processing Record48 of Set 13 | bella union
# Processing Record49 of Set 13 | wanning
# Processing Record50 of Set 13 | alunitdag
# City not found. Skipping...
# Processing Record1 of Set 14 | lagoa santa
# Processing Record2 of Set 14 | tabou
# Processing Record3 of Set 14 | grand-lahou
# Processing Record4 of Set 14 | sainte-maxime
# Processing Record5 of Set 14 | havre-saint-pierre
# Processing Record6 of Set 14 | hambantota
# Processing Record7 of Set 14 | pilar
# Processing Record8 of Set 14 | sabang
# Processing Record9 of Set 14 | koromilea
# City not found. Skipping...
# Processing Record10 of Set 14 | kropotkin
# Processing Record11 of Set 14 | kiruna
# Processing Record12 of Set 14 | alenquer
# Processing Record13 of Set 14 | bolshaya glushitsa
# Processing Record14 of Set 14 | biga
# Processing Record15 of Set 14 | nichinan
# Processing Record16 of Set 14 | lavrentiya
# Processing Record17 of Set 14 | dunedin
# Processing Record18 of Set 14 | doaba
# Processing Record19 of Set 14 | husavik
# Processing Record20 of Set 14 | marystown
# Processing Record21 of Set 14 | mahajanga
# Processing Record22 of Set 14 | destin
# Processing Record23 of Set 14 | lithakia
# Processing Record24 of Set 14 | zarechnyy
# Processing Record25 of Set 14 | sawang daen din
# Processing Record26 of Set 14 | arroyo
# Processing Record27 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record28 of Set 14 | mao
# Processing Record29 of Set 14 | junin
# Processing Record30 of Set 14 | acarau
# Processing Record31 of Set 14 | yenagoa
# Processing Record32 of Set 14 | sri aman
# Processing Record33 of Set 14 | lata
# Processing Record34 of Set 14 | pimentel
# Processing Record35 of Set 14 | urengoy
# Processing Record36 of Set 14 | lezhe
# Processing Record37 of Set 14 | delfzijl
# Processing Record38 of Set 14 | timmins
# Processing Record39 of Set 14 | mujiayingzi
# Processing Record40 of Set 14 | salimpur
# Processing Record41 of Set 14 | evansville
# Processing Record42 of Set 14 | yumen
# Processing Record43 of Set 14 | yeppoon
# Processing Record44 of Set 14 | casino
# Processing Record45 of Set 14 | la ronge
# Processing Record46 of Set 14 | inhuma
# Processing Record47 of Set 14 | gimry
# Processing Record48 of Set 14 | chamonix-mont-blanc
# Processing Record49 of Set 14 | hervey bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Georgetown   5.4112  100.3354     80.53        83          20        5.75
# 1    Khatanga  71.9667  102.5000     -1.86        97          99       10.25
# 2        Faya  18.3851   42.4509     61.32        74           6        3.47
# 3      Lashio  22.9333   97.7500     56.10        96           0        1.39
# 4      Burnie -41.0667  145.9167     51.03        75          88        8.08
# 5  Kaitangata -46.2817  169.8464     42.91        94         100        4.25
# 6      Itoman  26.1247  127.6694     68.02        73          75       11.50
# 7  Codrington -38.2667  141.9667     49.84        88          13       10.27
# 8   Hithadhoo  -0.6000   73.0833     81.12        71          76       13.58
# 9   Perpignan  42.7500    2.7500     46.04        53           0       14.97
#
#   Country Current Description
# 0      MY          few clouds
# 1      RU     overcast clouds
# 2      SA           clear sky
# 3      MM           clear sky
# 4      AU     overcast clouds
# 5      NZ     overcast clouds
# 6      JP       broken clouds
# 7      AU          few clouds
# 8      MV       broken clouds
# 9      FR           clear sky

# %%
#Rearrange column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
#Reassigning data frame with rearrange column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Georgetown      MY   5.4112  100.3354     80.53        83          20
# 1    Khatanga      RU  71.9667  102.5000     -1.86        97          99
# 2        Faya      SA  18.3851   42.4509     61.32        74           6
# 3      Lashio      MM  22.9333   97.7500     56.10        96           0
# 4      Burnie      AU -41.0667  145.9167     51.03        75          88
# 5  Kaitangata      NZ -46.2817  169.8464     42.91        94         100
# 6      Itoman      JP  26.1247  127.6694     68.02        73          75
# 7  Codrington      AU -38.2667  141.9667     49.84        88          13
# 8   Hithadhoo      MV  -0.6000   73.0833     81.12        71          76
# 9   Perpignan      FR  42.7500    2.7500     46.04        53           0
#
#    Wind Speed Current Description
# 0        5.75          few clouds
# 1       10.25     overcast clouds
# 2        3.47           clear sky
# 3        1.39           clear sky
# 4        8.08     overcast clouds
# 5        4.25     overcast clouds
# 6       11.50       broken clouds
# 7       10.27          few clouds
# 8       13.58       broken clouds
# 9       14.97           clear sky

# %%
#Create the output file(CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
